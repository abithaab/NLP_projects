# %%
import nltk
from nltk. tokenize import word_tokenize
from nltk. corpus import stopwords
from nltk. stem import porterastemmer

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# %%
text = "Natural Language processing enables machine to understand human language."

# %%
import nltk
nltk.download('punkt_tabs')
tokens = word_tokenize(text)
tokens

# %%
stop_words = set(stopwords.words('english'))
filtered tokens = [word for word in tokens if word.lower()not in stop_words]

# %%
#stemming
ps = porterstemmer()
stemmed_tokens = [ps.stem(word) for word in filtered_tokens]

# %%
lemmatizer = WordNetLemmatizer()
lemmatizer_tokens = [lemmatizer.lemmatize(word)for word in filtered_tokens]

# %%
print("Tokens:",tokens)
print("Filtered Tokens:",filterd_tokens)
print("Stemmed Tokens:",stemmed_tokens)
print("Lemmatized Tokens:",lemmatized_tokens)
