# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
#dowload resources
nltk_download('punkt')
nltk_download('avereged_perceptron_tagger')

# %%
#sampple sentence
sentence = "Natural Language processing helps computers understand human langauage."

# %%
#tokenization
tokens = word_tokenize(sentence)

# %%
#pos tagging
tags = pos_tag(tokens)
print("POS Tags:",tags)
