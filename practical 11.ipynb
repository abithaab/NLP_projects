# %%
import numpy as np           
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
import joblib

# %%
#dataset (hours vs mark)
x = np.array([[1],[2],[3],[4],[5],[6],[7],[8]])
y = np.array([40,45,50,60,65,70,75,85])

# %%
x_train, x_test, x_train, y_test = train_tesst_split(x,y, test_size = 0.3, random_state=1)

# %%
#train model
model = linearregression()
model.fit(x_train, y_train)

# %%
#prediction
y_pred = model.predit(x_test)

# %%
#evaluation
print("actual mark:", y_pred)
print("predicted mark:", y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE:", rmse)

print("R2 score:",r2_score(y_test, y_pred))
