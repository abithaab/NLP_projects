# %%
from textblob import textBlob

# %%
#sample reviews
reviewa = [
    "i love this prodect, it is amazing!",
    "this is the worst purchase i never made.",
    "the product is okey, notgreat."
]

# %%
#sentiment analysis
for review in review:
    blob = text Blob(review)
    polarity = blob.sentiment.polarity
    if polarity > 0:
        sentiment = "positive"
    elif polarity < 0:
        sentiment = "negative"
    else:
        sentiment = "neutral"
        print(f"review: {review}\nsentiment:{sentiment}\npolarity:{polarity}\n")
