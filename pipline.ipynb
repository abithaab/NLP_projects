# %%
#import libraries
import nltk

# %%
#import mltk
download datasets
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('maunt_ne_chunker')
nltk.download('words')
nltk.download()

# %%
#sample text
text = "Artificial Intelligence is changing the world.Google is located in USA"

# %%
#segmentation
from.nltk.tokenize import sent_tokenize 
sentences = sent_tokinize(text)
print("segmentation",sentence)

# %%
#tokenization
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
print("tokenization",tokens)

# %%
#stemming
from nltk.stem import porterstemmer
ps = porterstemmmer()
stemmed = [ps.stem(w)for w in tokens]
prinnt("stemming,"stemmed)

# %%
#lemmatization
from nltk.stem import wordnetlemnatizer
lemm = wordnet lemmatizer()
lemmatizer = [lemm.lemmatize(w)for wintokens]
print("lemmatization",lemmatized)

# %%
#pos_tagging
pos_tags = nltk.pos_tags(tokens)
print("pos tagging:",pos_tags)

# %%
#NER
named_entities = nltk.ne_chunk(pos_tags)
print("named entities:",named_entities)
