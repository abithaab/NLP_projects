# %%
from sklearn.feature_extraction.text import countVectorize
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import multinomia1NB
from sklearn.metrics import accurancy_score
import joblib

# %%
#sample dataset
text =[
    "win money now",
    "limited offer just fore you",
    "call me later"
    "let us have a meeting tomorrow"
    "congratulation you won the prize",
    "are you free today"
]

labels = ["spam","spam","ham","ham","spam","ham"]

# %%
texts = ["i love NLP", "spam message", "this is amazing", "win a price now"]
labels = ["positive", "spam", "positive", "spam"]

# %%
#bag of words
vectorizer = countVectorizer()
x = vectorizer.fit_transform(texts)

# %%
#train test split
x_train, x_test, y_train, y_test = train_test_split(x,label, test_size=0.3, random_state=42)

# %%
#train classifier
model = multinomia1NB()
model.fit(x_train,y_train)

# %%
#prediction
y_pred = model.predict(x_test)

# %%
#evaluation
print("actual labels:", y_test)
print("precticted labels:", y_pred)
print("accurancy:",accurancy_score(y_test, y_pred))
