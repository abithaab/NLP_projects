# %%
# !pip install nltk

# %%
import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\ABITHA
# [nltk_data]     E\AppData\Roaming\nltk_data...

# %%
lemmatizer = WordNetLemmatizer()

# %%
word = "meeting"
lemma = lemmatizer.lemmatize(word,pos='v')
print(f"lemmatized word:{lemma}")

# %%
1 word = "flew"
2 lemma = lemmatizer.lemmatize(word,pos='v')
3 print(f"Lemmatizer Word:{lemma}")

# %%
1 word = "drawing"
2 lemma = lemmatizer.lemmatize(word,pos='v')
3 print(f"Lemmatizer Word:{lemma}")

# %%
1 word = "run"
2 lemma = lemmatizer.lemmatize(word,pos='v')
3 print(f"Lemmatizer Word:{lemma}")

# %%
1 word = "draw"
2 lemma = lemmatizer.lemmatize(word,pos='v')
3 print(f"Lemmatizer Word:{lemma}")

# %%
from nltk import pos_tag
from nltk.tokenize import word_tokenizze
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
sentence = "The dogs are running"
tokens = word_tokenize(sentence)
tagged = pos_tag(tokens)

lemmatized_word = {lemmatizer.lemmatize(
            word, pose'v' if tag.startswith('v') else 'n')for word,tag in tagged}
print(lemmatized_word)
#Task : apply for sentence: "I am Studing book"

# %%
lemmatizer = WordNetLemmatizer()
sentence = "I am Studing book"

tokens = word_tokenize(sentence)
tagged = pos_tag(tokens)

lemmatized_word = {lemmatizer.lemmatize(
            word, pose'v' if tag.startswith('v') else 'n')for word,tag in tagged}
print(lemmatized_word)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')

# %%
text = "NLTK is a powerful library for natural language processing."
word = word_tokenize(text)

# %%
pos_tags = pos_tag(words)

# %%
print("orginal Text:")
print(text)

print("\nPOS tagging result:")
for word,pos_tags in pos_tags:
    print(f"{word}: {pos_tags}")
    #the quick brown fox jumps over the lazy dog

# %%
text = "The quick brown fox jumps over the lazy dog."
words = word_tokenize(text)

pos_tags = pos_tag(words)

print("orginal taxt:")
print(text)

print("\nPOS tagging result:")
for word,pos_tags in pos_tags:
    print(f"{word}: {pos_tags}")
