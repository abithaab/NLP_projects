# %%
from sklearn.feature extraction.text import countVectorizer, TfidfVectorizer

# %%
#sample corpus
corbus = [
    "natural language processing is fun.",
    "text processing is an important NLP steps."
]

# %%
#bag of words
bow = countVectorizer()
bow_mattrix = bow.fit_transform(corpus)
print("bow feature names:",bow.get_feature_names_out())
print("bow matrix:\n", bow_matrix.toarray())
